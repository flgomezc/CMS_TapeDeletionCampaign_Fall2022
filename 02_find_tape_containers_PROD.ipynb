# %%
PUBLIC_PATH = "/eos/user/f/fgomezco/www/"

# %%
from datetime import datetime

import click
import os
import pandas as pd
from dateutil.relativedelta import relativedelta
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    col, collect_list, countDistinct, concat_ws, 
    greatest, lit, lower, udf, when, from_unixtime, split,
    avg as _avg,
    count as _count,
    hex as _hex,
    max as _max,
    min as _min,
    round as _round,
    sum as _sum,
    desc as _desc,
)

from pyspark.sql.types import (
    LongType,
    StringType,
)

TODAY = datetime.today().strftime('%Y-%m-%d')

print(TODAY)

# https://github.com/dmwm/CMSKubernetes/tree/master/docker/sqoop/scripts
HDFS_RUCIO_CONTENTS = "/project/awg/cms/rucio/{}/contents/part*.avro".format(TODAY)
HDFS_RUCIO_REPLICAS = "/project/awg/cms/rucio/{}/replicas/part*.avro".format(TODAY)
HDFS_RUCIO_DIDS     = "/project/awg/cms/rucio/{}/dids/part*.avro".format(TODAY)
HDFS_RUCIO_LOCKS    = "/project/awg/cms/rucio/{}/locks/part*.avro".format(TODAY)
HDFS_RUCIO_RSES     = "/project/awg/cms/rucio/{}/rses/part*.avro".format(TODAY)
HDFS_RUCIO_RULES     = "/project/awg/cms/rucio/{}/rules/part*.avro".format(TODAY)

pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

def get_rse_ids(rse_name):
    df_target_rse = df_rses.filter(col("rse") == rse_name).toPandas()
    return df_target_rse['rse_id'].iloc[0]

# Get the Contents Table (dataset-file table)
df_contents_f = spark.read.format('avro').load(HDFS_RUCIO_CONTENTS) \
    .filter(col("CHILD_TYPE").contains('F')) \
    .withColumnRenamed("NAME", 'parent_did') \
    .withColumnRenamed("CHILD_NAME", 'child_name') \
    .withColumn('size_bytes', col('BYTES').cast(LongType())) \
    .select(["child_name", "parent_did", "size_bytes"]) \
#    .withColumnRenamed("BYTES", 'size_bytes') \
# Out:
# 2022-09-28

# %%
df_replicas_main = spark.read.format('avro').load(HDFS_RUCIO_REPLICAS) \
    .filter(col("STATE") == 'A') \
    .withColumn('f_name', col('NAME')) \
    .withColumn('replica_rse_id', lower(_hex(col('RSE_ID')))) \
    .withColumn('f_size', col('BYTES').cast(LongType())) \
    .withColumn('created_at', from_unixtime(col('CREATED_AT')/1000)) \
    .select(['replica_rse_id','f_name','f_size','created_at'])

# %%
# Get the RSEs table
df_target_rses = spark.read.format('avro').load(HDFS_RUCIO_RSES) \
    .withColumnRenamed("RSE", "rse") \
    .withColumn('rse_id', lower(_hex(col('ID')))) \
    .select(['rse_id', 'rse']) \
    .filter( \
            ( col('rse').contains("_Tape") ) & \
            ( ~ col('rse').contains("T3_") ) & \
            ( ~ col('rse').contains("T2_") ) & \
            ( ~ col('rse').contains("Temp") ) & \
            ( ~ col('rse').contains("Test") ) ) \
    .toPandas()

# %%
df_target_rses
# Out:
#                              rse_id                 rse
# 0  dbdaf50ee9d24f92ad24473539522204     T1_US_FNAL_Tape
# 1  f091e56ff0f440e28db115dada9fc97e      T1_ES_PIC_Tape
# 2  515d41d70dd843098f0029b9ae6b4914      T1_UK_RAL_Tape
# 3  89a267a997d74de6850af9442e21d2a8     T1_IT_CNAF_Tape
# 4  f44c866a264d4da9972969e9f3b5bb52     T0_CH_CERN_Tape
# 5  5017683aea934c46b94bac226f086e53  T1_FR_CCIN2P3_Tape
# 6  71b2e6c1a389439d9363dee61bf2aa04     T1_RU_JINR_Tape
# 7  3d355ce4f055410daf0ea660e77eb73d      T1_DE_KIT_Tape

# %%
df_rses = spark.read.format('avro').load(HDFS_RUCIO_RSES)\
    .withColumnRenamed("RSE", "rse") \
    .withColumn('rse_id', lower(_hex(col('ID')))) \
    .select(['rse_id', 'rse']) \
    .filter( \
            ( col('rse').contains("_Tape") ) & \
            ( ~ col('rse').contains("T3_") ) & \
            ( ~ col('rse').contains("T2_") ) & \
            ( ~ col('rse').contains("Temp") ) & \
            ( ~ col('rse').contains("Test") ) )

# %%
df_replicas_tapes = df_replicas_main.join(df_rses.withColumnRenamed('rse_id', 'replica_rse_id'), ['replica_rse_id'], how='left').dropna().select(['rse', 'replica_rse_id', 'f_name', 'f_size', 'created_at'])

# %%
df_replicas_tapes
# Out:
# DataFrame[rse: string, replica_rse_id: string, f_name: string, f_size: bigint, created_at: string]

# %%
df_tape_contents = df_replicas_tapes.join( df_contents_f.withColumnRenamed('parent_did', 'dataset') \
                                          , df_replicas_tapes["f_name"] == df_contents_f["child_name"], how="left") \
    .select(['rse', 'f_name', 'f_size', 'created_at', 'dataset'])

# %%
aux = df_tape_contents.groupby(['rse', 'dataset']).agg(_sum('f_size').alias('size_bytes'), _max('created_at').alias('max_created_at'), _min('created_at').alias('min_created_at'))

# %%
aux = aux.withColumn("container", split(aux["dataset"], "#").getItem(0))

# %%
aux
# Out:
# DataFrame[rse: string, dataset: string, size_bytes: bigint, max_created_at: string, min_created_at: string, container: string]

# %%
aux = aux.withColumn("tier", split(aux["container"], "/").getItem(3))

# %%
DF = aux.groupBy(['rse', 'container', 'tier']) \
    .agg(_sum('size_bytes').alias('size_bytes'), \
         _max('max_created_at').alias('max_created_at'), \
         _min('min_created_at').alias('min_created_at'))

# %%
DF
# Out:
# DataFrame[rse: string, container: string, tier: string, size_bytes: bigint, max_created_at: string, min_created_at: string]

# %%
DF.limit(100).toPandas()
# Out:
#                 rse  \
# 0   T0_CH_CERN_Tape
# 1   T0_CH_CERN_Tape
# 2   T0_CH_CERN_Tape
# 3   T0_CH_CERN_Tape
# 4   T0_CH_CERN_Tape
# 5   T0_CH_CERN_Tape
# 6   T0_CH_CERN_Tape
# 7   T0_CH_CERN_Tape
# 8   T0_CH_CERN_Tape
# 9   T0_CH_CERN_Tape
# 10  T0_CH_CERN_Tape
# 11  T0_CH_CERN_Tape
# 12  T0_CH_CERN_Tape
# 13  T0_CH_CERN_Tape
# 14  T0_CH_CERN_Tape
# 15  T0_CH_CERN_Tape
# 16  T0_CH_CERN_Tape
# 17  T0_CH_CERN_Tape
# 18  T0_CH_CERN_Tape
# 19  T0_CH_CERN_Tape
# 20  T0_CH_CERN_Tape
# 21  T0_CH_CERN_Tape
# 22  T0_CH_CERN_Tape
# 23  T0_CH_CERN_Tape
# 24  T0_CH_CERN_Tape
# 25  T0_CH_CERN_Tape
# 26  T0_CH_CERN_Tape
# 27  T0_CH_CERN_Tape
# 28  T0_CH_CERN_Tape
# 29  T0_CH_CERN_Tape
# 30  T0_CH_CERN_Tape
# 31  T0_CH_CERN_Tape
# 32  T0_CH_CERN_Tape
# 33  T0_CH_CERN_Tape
# 34  T0_CH_CERN_Tape
# 35  T0_CH_CERN_Tape
# 36  T0_CH_CERN_Tape
# 37  T0_CH_CERN_Tape
# 38  T0_CH_CERN_Tape
# 39  T0_CH_CERN_Tape
# 40  T0_CH_CERN_Tape
# 41  T0_CH_CERN_Tape
# 42  T0_CH_CERN_Tape
# 43  T0_CH_CERN_Tape
# 44  T0_CH_CERN_Tape
# 45  T0_CH_CERN_Tape
# 46  T0_CH_CERN_Tape
# 47  T0_CH_CERN_Tape
# 48  T0_CH_CERN_Tape
# 49  T0_CH_CERN_Tape
# 50  T0_CH_CERN_Tape
# 51  T0_CH_CERN_Tape
# 52  T0_CH_CERN_Tape
# 53  T0_CH_CERN_Tape
# 54  T0_CH_CERN_Tape
# 55  T0_CH_CERN_Tape
# 56  T0_CH_CERN_Tape
# 57  T0_CH_CERN_Tape
# 58  T0_CH_CERN_Tape
# 59  T0_CH_CERN_Tape
# 60  T0_CH_CERN_Tape
# 61  T0_CH_CERN_Tape
# 62  T0_CH_CERN_Tape
# 63  T0_CH_CERN_Tape
# 64  T0_CH_CERN_Tape
# 65  T0_CH_CERN_Tape
# 66  T0_CH_CERN_Tape
# 67  T0_CH_CERN_Tape
# 68  T0_CH_CERN_Tape
# 69  T0_CH_CERN_Tape
# 70  T0_CH_CERN_Tape
# 71  T0_CH_CERN_Tape
# 72  T0_CH_CERN_Tape
# 73  T0_CH_CERN_Tape
# 74  T0_CH_CERN_Tape
# 75  T0_CH_CERN_Tape
# 76  T0_CH_CERN_Tape
# 77  T0_CH_CERN_Tape
# 78  T0_CH_CERN_Tape
# 79  T0_CH_CERN_Tape
# 80  T0_CH_CERN_Tape
# 81  T0_CH_CERN_Tape
# 82  T0_CH_CERN_Tape
# 83  T0_CH_CERN_Tape
# 84  T0_CH_CERN_Tape
# 85  T0_CH_CERN_Tape
# 86  T0_CH_CERN_Tape
# 87  T0_CH_CERN_Tape
# 88  T0_CH_CERN_Tape
# 89  T0_CH_CERN_Tape
# 90  T0_CH_CERN_Tape
# 91  T0_CH_CERN_Tape
# 92  T0_CH_CERN_Tape
# 93  T0_CH_CERN_Tape
# 94  T0_CH_CERN_Tape
# 95  T0_CH_CERN_Tape
# 96  T0_CH_CERN_Tape
# 97  T0_CH_CERN_Tape
# 98  T0_CH_CERN_Tape
# 99  T0_CH_CERN_Tape
#
#                                                                                                                                                                      container  \
# 0                                                       /ADDGravToGG_NegInt-0_LambdaT-6500_M-4000To6500_TuneCP2_13TeV-pythia8/RunIIFall17GS-93X_mc2017_realistic_v3-v1/GEN-SIM
# 1                           /ADDGravToGG_NegInt-0_LambdaT-7000_M-1000To2000_TuneCP2_13TeV-pythia8/RunIIFall17MiniAODv2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/MINIAODSIM
# 2                                                          /ADDGravToLL_LambdaT-10000_M-2000ToInf_13TeV-pythia8/RunIIAutumn18DRPremix-102X_upgrade2018_realistic_v15-v1/AODSIM
# 3                                        /ADDGravToLL_LambdaT-8000_M-800To1300_13TeV-pythia8/RunIIFall17MiniAODv2-PU2017_12Apr2018_94X_mc2017_realistic_v14_ext1-v1/MINIAODSIM
# 4                              /ADDGravToLL_LambdaT-9000_M-1300To2000_13TeV-pythia8/RunIIFall17NanoAODv5-PU2017_12Apr2018_Nano1June2019_102X_mc2017_realistic_v7-v1/NANOAODSIM
# 5                                                            /ADDmonoPhoton_MD-1_d-3_TuneCP5_13TeV-pythia8/RunIISummer20UL18RECO-106X_upgrade2018_realistic_v11_L1v1-v2/AODSIM
# 6                       /ADDmonoPhoton_MD-1_d-3_TuneCUETP8M1_13TeV-pythia8/RunIIFall15DR76-25nsFlat10to50ZsecalNzshcalRaw_76X_mcRun2_asymptotic_2016EcalTune_30fb_v1-v1/AODSIM
# 7                                                                                                                                             /AlCaLumiPixels2/Run2017G-v1/RAW
# 8                                                                                                                                             /AlCaLumiPixels3/Run2018C-v1/RAW
# 9                    /AxialMonoW_Mphi-300_Mchi-300_gSM-0p25_gDM-1p0_v2_13TeV-madgraph/RunIISummer16NanoAODv4-PUMoriond17_Nano14Dec2018_102X_mcRun2_asymptotic_v6-v1/NANOAODSIM
# 10                                    /AxialMonoW_Mphi-750_Mchi-1_gSM-0p25_gDM-1p0_v2_13TeV-madgraph/RunIISummer16MiniAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/MINIAODSIM
# 11                 /Axial_MonoW_NLO_Mphi-500_Mchi-150_gSM-0p25_gDM-1p0_13TeV-madgraph/RunIISummer16NanoAODv5-PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/NANOAODSIM
# 12                                                  /B0ToMMK0sPiPi_ResRho_Filter_DGamma0_TuneCP5_13TeV-pythia8-evtgen/RunIISummer20UL17RECO-106X_mc2017_realistic_v6-v2/AODSIM
# 13  /BToHNLEMuX_HNLToEMuPi_SoftQCD_b_mHNL4p5_ctau10p0mm_TuneCP5_13TeV-pythia8-evtgen/RunIIAutumn18RECOBParking-Custom_RDStar_BParking_102X_upgrade2018_realistic_v15-v2/AODSIM
# 14                       /BdToDstarMuNu_SoftQCDnonD_TuneCP5_13TeV-pythia8-evtgen/RunIIAutumn18MiniAOD-Custom_RDStar_BParking_102X_upgrade2018_realistic_v15_ext2-v3/MINIAODSIM
# 15                                  /BlackHole_BH1_MD-3000_MBH-10000_n-2_TuneCUETP8M1_13TeV-blackmax/RunIISummer16NanoAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/NANOAODSIM
# 16                           /BlackHole_BH1_MD-4000_MBH-5000_n-2_TuneCUETP8M1_13TeV-blackmax/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 17                           /BlackHole_BH2_MD-5000_MBH-6000_n-6_TuneCUETP8M1_13TeV-blackmax/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 18                                   /BlackHole_BH5_MD-2000_MBH-5000_n-6_TuneCUETP8M1_13TeV-blackmax/RunIISummer16MiniAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/MINIAODSIM
# 19                               /BlackHole_BH5_MD-3000_MBH-4000_n-2_TuneCUETP8M1_13TeV-blackmax/RunIIFall15MiniAODv2-PU25nsData2015v1_76X_mcRun2_asymptotic_v12-v1/MINIAODSIM
# 20                                    /BlackHole_BH6_MD6000_MBH11000_n4_13TeV_TuneCUETP8M1-charybdis/RunIISummer16MiniAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/MINIAODSIM
# 21                             /BlackHole_BH8_MD2000_MBH4000_n6_13TeV_TuneCUETP8M1-charybdis/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 22                             /BlackHole_BH9_MD3000_MBH8000_n2_13TeV_TuneCUETP8M1-charybdis/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 23                 /BprimeBToBZ_M-700_Width-10p_TuneCUETP8M2T4_13TeV-madgraph-pythia8/RunIISummer16NanoAODv4-PUMoriond17_Nano14Dec2018_102X_mcRun2_asymptotic_v6-v2/NANOAODSIM
# 24                            /BprimeBToTW_M-1400_Width-30p_LH_TuneCUETP8M2T4_13TeV-madgraph-pythia8/RunIISummer16MiniAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/MINIAODSIM
# 25                         /BprimeTToHB_M-1000_LH_TuneCUETP8M1_13TeV-madgraph-pythia8/RunIISummer16NanoAODv5-PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/NANOAODSIM
# 26                                    /BprimeTToZB_M-1700_RH_TuneCUETP8M1_13TeV-madgraph-pythia8/RunIIFall15MiniAODv2-PU25nsData2015v1_76X_mcRun2_asymptotic_v12-v2/MINIAODSIM
# 27           /BsToJPsiPhi_JPsiToMuMu_PhiToKK_EtaPtFilter_SoftQCDnonD_TuneCP5_13TeV-pythia8-evtgen/RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v1/MINIAODSIM
# 28                                       /BstarToTW_M-2800_LH_TuneCP5_13TeV-madgraph-pythia8/RunIIAutumn18NanoAODv4-Nano14Dec2018_102X_upgrade2018_realistic_v16-v1/NANOAODSIM
# 29                                     /BulkGravToWWToWhadWhad_narrow_M-2000_TuneCP5_13TeV-madgraph-pythia/RunIISummer20UL16RECOAPV-106X_mcRun2_asymptotic_preVFP_v8-v2/AODSIM
# 30                                         /BulkGravToZZToZhadZhad_narrow_M-4000_TuneCP5_13TeV-madgraph-pythia/RunIISummer20UL17MiniAOD-106X_mc2017_realistic_v6-v2/MINIAODSIM
# 31                                /BulkGravToZZToZhadZhad_narrow_M-500_13TeV-madgraph/RunIISummer16NanoAODv5-PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/NANOAODSIM
# 32                            /BulkGravToZZToZhadZhad_narrow_M-7000_TuneCP5_13TeV-madgraph-pythia/RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v2/MINIAODSIM
# 33               /BulkGravTohhTohVVhbb_narrow_M-1000_TuneCP5_13TeV-madgraph-pythia8/RunIIFall17NanoAODv5-PU2017_12Apr2018_Nano1June2019_102X_mc2017_realistic_v7-v1/NANOAODSIM
# 34                          /BulkGravTohhTohWWhbb_width0p05_M-3800_TuneCP2_13TeV-madgraph_pythia8/RunIIFall17MiniAODv2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/MINIAODSIM
# 35                               /BulkGravitonToHHTo4Q_MX2000_MH27_TuneCP5_13TeV-madgraph_pythia8/RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v3/MINIAODSIM
# 36                              /BulkGravitonToHHTo4Q_MX5900_MH330_TuneCP5_13TeV-madgraph_pythia8/RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v3/MINIAODSIM
# 37                        /BulkGraviton_ggF_ZZ_ZlepZhad_narrow_M5000_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL18MiniAOD-106X_upgrade2018_realistic_v11_L1v1-v2/MINIAODSIM
# 38                                                 /CITo2E_M300_CUETP8M1_Lam10TeVConRR_13TeV-pythia8/RunIISummer16NanoAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/NANOAODSIM
# 39                                                /CITo2Mu_M800_CUETP8M1_Lam16TeVDesLR_13TeV-pythia8/RunIISummer16NanoAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/NANOAODSIM
# 40                                     /ChargedHiggsToTauNu_IntermediateNoNeutral_M140_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17RECO-106X_mc2017_realistic_v6-v3/AODSIM
# 41                /ChargedHiggs_HplusTB_HplusToTauNu_HeavyMass_M-2000_13TeV_amcatnlo_pythia8/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 42           /ChargedHiggs_HplusToTauNu_IntermediateNoNeutral_M200_TuneCP5_13TeV-madgraph-pythia8/RunIIFall17MiniAODv2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/MINIAODSIM
# 43                                  /Chib0ToUps1SMuMu_Testm50_TuneCUEP8M1_13TeV-pythia8/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2_ext1-v1/NANOAODSIM
# 44                                                                                                                                           /Commissioning_0T/Run2015D-v1/RAW
# 45                     /DMS_NNPDF30_Scalar_Mphi-350_Mchi-100_gSM-1p0_gDM-1p0_v2_13TeV-powheg/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 46                      /DMS_NNPDF30_Scalar_Mphi-500_Mchi-50_gSM-1p0_gDM-1p0_v2_13TeV-powheg/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 47                                                    /DMSimp_MonoZLL_Scalar_TuneCP5_GQ1p0_GDM1p0_MY0-450_mxd-1/RunIIAutumn18DRPremix-102X_upgrade2018_realistic_v15-v1/AODSIM
# 48             /DMV_NNPDF30_Axial_Mphi-2500_Mchi-600_gSM-0p25_gDM-1p0_v2_13TeV-powheg/RunIISummer16NanoAODv4-PUMoriond17_Nano14Dec2018_102X_mcRun2_asymptotic_v6-v2/NANOAODSIM
# 49                           /DMV_NNPDF30_Axial_Mphi-50_Mchi-50_gSM-0p25_gDM-1p0_v2_13TeV-powheg/RunIIFall15MiniAODv2-PU25nsData2015v1_76X_mcRun2_asymptotic_v12-v1/MINIAODSIM
# 50          /DM_mPhoton_NLO_Vector_Mphi-500_Mchi-50_gSM-0p25_gDM-1p0_pta130_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL18RECO-106X_upgrade2018_realistic_v11_L1v1-v2/AODSIM
# 51                                          /DYBJetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/RunIISummer16NanoAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/NANOAODSIM
# 52                                            /DYJetsToLL_1J_MLL_800_1400_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9-v4/MINIAODSIM
# 53                                  /DYJetsToLL_2J_MLL_200_400_TuneCP5_13TeV-amcatnloFXFX-pythia8/RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v4/MINIAODSIM
# 54                                            /DYJetsToMuMu_M-50_TuneCP5_14TeV-madgraphMLM-pythia8/Run3Winter21DRMiniAOD-designGT_112X_mcRun3_2021_realistic_v16-v2/MINIAODSIM
# 55                 /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8/RunIISummer16NanoAODv5-PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/NANOAODSIM
# 56                                                            /DYToLL-M-50_2J_14TeV-madgraphMLM-pythia8/PhaseIISpr18AODMiniAOD-noPU_93X_upgrade2023_realistic_v5-v1/MINIAODSIM
# 57                              /DYTypeIHeavyN-DFmix_Dilepton_MN1000_TuneCP5_13TeV-amcatnlo-pythia8/RunIISummer20UL16MiniAODAPV-106X_mcRun2_asymptotic_preVFP_v8-v2/MINIAODSIM
# 58         /DarkHiggs_MonoHs_HsToWWTo2l2nu_mhs_200_mx_300_mZp_1000_TuneCP5_13TeV-madgraph-pythia8/RunIIFall17MiniAODv2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v2/MINIAODSIM
# 59                                         /DarkMatter_LowEt_PhotonMet_DM-50_Med-3000_Width-8pi_VectorUNI_TuneZ2star_8TeV-madgraph/Summer12_DR53X-PU_S10_START53_V19-v1/AODSIM
# 60    /DarkMatter_MonoPhoton_NLO_Axial_Mx-10_Mv-500_gDM1_gQ0p25_pta130_13TeV-madgraph/RunIISummer16MiniAODv2-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/MINIAODSIM
# 61                /DarkMatter_MonoPhoton_NLO_Vector_Mx-1000_Mv-10_gDM1_gQ0p25_13TeV-madgraph/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 62                               /DarkMatter_MonoPhoton_V_Mx-150_Mv-500_gDMgQ1_LO_13TeV-madgraph/RunIIFall15MiniAODv2-PU25nsData2015v1_76X_mcRun2_asymptotic_v12-v1/MINIAODSIM
# 63     /DarkMatter_MonoZToLL_NLO_Axial_Mx-150_Mv-500_gDM1_gQ0p25_TuneCUETP8M1_13TeV-madgraph/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 64       /DarkMatter_MonoZToLL_NLO_Scalar_Mx-100_Mv-500_gDM1_gQ1_TuneCUETP8M1_13TeV-madgraph/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 65          /DarkMatter_MonoZToLL_NLO_Scalar_Mx-1_Mv-50_gDM1_gQ1_TuneCUETP8M1_13TeV-madgraph/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 66                                                                                 /DarkMatter_Monojet_M-700_AVd_TuneZ2_8TeV-madgraph/Summer12_DR53X-PU_S10_START53_V7A-v1/DQM
# 67                                                  /DarkMatter_Monophoton_DM-50_Med-10000_Width-8_VectorUNI_TuneZ2star_8TeV-madgraph/Summer12_DR53X-PU_S10_START53_V19-v1/DQM
# 68                                 /DarkPhotonToMuMu_M30_madgraph_pythia8_TuneCUEP8M1/RunIISummer16NanoAODv5-PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/NANOAODSIM
# 69                                   /DarkSUSY_mH_125_mN1_10_mGammaD_1p5_cT_50_13TeV_pythia8/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2-v1/NANOAODSIM
# 70                                             /DarkSUSY_mH_125_mN1_60_mGammaD_10_cT_2_13TeV_pythia8/RunIISummer16MiniAODv3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2/MINIAODSIM
# 71                      /DarkShowerHiggs_darkphoton_M15_CTAU5000_XIOMEGA1_XILAMBDA1_TuneCP5_13TeV-powheg-pythia8/RunIIFall17DRPremix-PU2017_94X_mc2017_realistic_v11-v1/AODSIM
# 72                                                   /DiPhotonJetsBox1BJet_MGG-80toInf_13TeV-sherpa/RunIISummer20UL16MiniAODAPV-106X_mcRun2_asymptotic_preVFP_v8-v3/MINIAODSIM
# 73                                                 /DiPhotonJetsBox_MGG-80toInf_13TeV-Sherpa/RunIIAutumn18NanoAODv5-Nano1June2019_102X_upgrade2018_realistic_v19-v1/NANOAODSIM
# 74                  /DisplacedSUSY_stopToBottom_M_1500_1000mm_TuneCUETP8M1_13TeV_pythia8/RunIISummer16DR80Premix-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM
# 75                                             /DisplacedSUSY_stopToLBottom_M_1400_1mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17RECO-106X_mc2017_realistic_v6-v2/AODSIM
# 76                         /DisplacedSUSY_stopToLBottom_M_600_1mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL16MiniAODAPVv2-106X_mcRun2_asymptotic_preVFP_v11-v2/MINIAODSIM
# 77                         /DisplacedSUSY_stopToLD_M_1000_1mm_TuneCP5_13TeV_pythia8/RunIIFall17NanoAODv4-PU2017_12Apr2018_Nano14Dec2018_102X_mc2017_realistic_v6-v1/NANOAODSIM
# 78                                                         /DisplacedSUSY_stopToLD_M_1400_1000mm_TuneCP5_13TeV_pythia8/RunIIFall18GS-102X_upgrade2018_realistic_v11-v1/GEN-SIM
# 79                                       /DisplacedSUSY_stopToLD_M_1600_0p1mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9-v2/MINIAODSIM
# 80                                       /DisplacedSUSY_stopToLD_M_300_30mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL16RECOAPV-106X_mcRun2_asymptotic_preVFP_v8-v2/AODSIM
# 81                                                      /DisplacedSUSY_stopToLD_M_400_10mm_TuneCP5_13TeV_pythia8/RunIIFall17DRPremix-PU2017_94X_mc2017_realistic_v11-v1/AODSIM
# 82                                       /DisplacedSUSY_stopToLD_M_400_30mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL16RECOAPV-106X_mcRun2_asymptotic_preVFP_v8-v2/AODSIM
# 83                                                   /DisplacedSUSY_stopToLD_M_800_1mm_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17RECO-106X_mc2017_realistic_v6-v2/AODSIM
# 84                                                                                                                                       /DoublePhotonHighPt/HIRun2013A-v1/RAW
# 85                                                /EWKWMinus2Jets_WToLNu_M-50_TuneCP5_13TeV-madgraph-pythia8/RunIIAutumn18MiniAOD-102X_upgrade2018_realistic_v15-v1/MINIAODSIM
# 86                                                               /ExcitedLepton_MuMuZ-3500_TuneCP5_13TeV-pythia8/RunIIFall17DRPremix-PU2017_94X_mc2017_realistic_v11-v1/AODSIM
# 87                                                                                                                                                /FEDMonitor/HIRun2013-v1/RAW
# 88                                                                                                                                                    /FSQJet2/Run2017H-v1/RAW
# 89                                                                       /GGToMuMu_Pt-25_Inel-Inel_13TeV-lpair/RunIISummer19UL17MiniAOD-106X_mc2017_realistic_v6-v2/MINIAODSIM
# 90                                      /GJet_Pt-20to40_DoubleEMEnriched_MGG-80toInf_TuneCP5_13TeV_Pythia8/RunIISummer20UL18RECO-106X_upgrade2018_realistic_v11_L1v1-v4/AODSIM
# 91                               /GJets_DR-0p4_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv4-Nano14Dec2018_102X_upgrade2018_realistic_v16-v1/NANOAODSIM
# 92                            /GJets_HT-200To400_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/RunIISummer16NanoAOD-PUMoriond17_05Feb2018_94X_mcRun2_asymptotic_v2_ext1-v1/NANOAODSIM
# 93                                                                                 /GMSB_Lambda-120_CTau-1_TuneZ2star_8TeV-pythia6/Summer12_DR53X-PU_S10_START53_V7A-v1/AODSIM
# 94                                                                              /GMSB_Lambda-120_CTau-6000_TuneZ2star_8TeV-pythia6/Summer12_DR53X-PU_S10_START53_V7A-v1/AODSIM
# 95                                          /GkkTogRadionTogVV_MGkk1250-MR830_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17MiniAODv2-106X_mc2017_realistic_v9-v3/MINIAODSIM
# 96                                        /GkkTogRadionTogVV_MGkk2000-MR180_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v2/MINIAODSIM
# 97                                                   /GkkTogRadionTogVV_MGkk2000-MR650_TuneCP5_13TeV-madgraph-pythia8/RunIISummer20UL17RECO-106X_mc2017_realistic_v6-v3/AODSIM
# 98                                                                                                                                       /GlobalMar08-A/Online-CMSSW_1_8_1/RAW
# 99                                                                             /GluGluHToBB_M125_13TeV_powheg_pythia8/RunIIFall18wmLHEGS-102X_upgrade2018_realistic_v11-v1/LHE
#
#           tier  sum(size_bytes)  max(max_created_at)  min(min_created_at)
# 0      GEN-SIM      58827294771  2020-10-02 00:20:47  2020-09-16 09:02:53
# 1   MINIAODSIM       4164135433  2020-10-02 02:57:07  2020-09-20 03:52:14
# 2       AODSIM      57203254927  2020-10-01 22:02:40  2020-09-20 03:58:45
# 3   MINIAODSIM       6860260968  2020-10-01 23:44:18  2020-09-16 08:46:28
# 4   NANOAODSIM        238363706  2020-06-26 07:54:10  2020-06-26 04:01:55
# 13                            FEVT               170    2268070566356801
# 14                             RAW              9838  102192814770247089
# 15                        ALCARECO              3500    7474173706786201
# 16                             DQM              7535       2247921550552
# 17                            TEST               180         48600000000
# 18                             AOD              4045   36528482014689274
# 19                            RECO               599    2567078343441145
# 20                      MINIAODSIM            165349   15600886424387509
# 21                    GEN-SIM-RECO               931    7269250970553662
# 22                    FEVTDEBUGHLT                17      44508484969031
# 23                         NANOAOD              2211      66010856331649
# 24                      ALCAPROMPT                11       1670678427953
# 25                          PREMIX                25    5837578999210829
# 26                       CONTAINER                15    1260697442484918
# 27                       RAWAODSIM                 1          3315613890
# 28                            None                 0      24535172091666
# 29                    GEN-SIM-DIGI                 1        247592117542
# 30  GEN-SIM-DIGI-RAW-HLTDEBUG-RECO                 1      45944994004079
# 31       GEN-SIM-DIGI-RAW-HLTDEBUG                 4      22845763444143

# %%
filename = "TapeDeletionCampaignFall2022_AllContainersAtTapeSites.csv"

# %%
DF_pandas = DF.toPandas()

# %%
! mkdir /eos/user/f/fgomezco/www/TapeDeletionCampaignFall2022/

# %%
DF_pandas.to_csv(path_or_buf=PUBLIC_PATH+filename)

# %%
spark.conf.set("spark.sql.debug.maxToStringFields", 200)

# %%
test = DF.groupBy(['Tier']).agg(_count('container'), _sum('sum(size_bytes)').alias('size_bytes'))

# %%
test.toPandas()
# Out:
#                               Tier  count(container)          size_bytes
# 0                              GEN               394     406459499015495
# 1                            DQMIO              1166      54609544501644
# 2                         RAW-RECO              1595    5003250155498196
# 3                          GEN-SIM              5647   10358942352110224
# 4                           AODSIM            101978   67021459653274068
# 5                 GEN-SIM-DIGI-RAW               897   14129363579283180
# 6                             USER              4498    4169489085168408
# 7         GEN-SIM-DIGI-RAW-MINIAOD               298     903496839030728
# 8                              LHE              7837     931755317460014
# 9                      GEN-SIM-RAW               222    1084039061945533
# 10                      NANOAODSIM            207970     448281422100372
# 11                         MINIAOD              5266    6156924765739158
# 12               GEN-SIM-RECODEBUG               139    1571622797386267
# 13                            FEVT               170    2268070566356801
# 14                             RAW              9692  101649298175763864
# 15                        ALCARECO              3453    7471032695729974
# 16                             DQM              7535       2247921550552
# 17                             AOD              4023   36526931920162017
# 18                            RECO               599    2567078343441145
# 19                      MINIAODSIM            161581   15480120999084623
# 20                    GEN-SIM-RECO               931    7269250970553662
# 21                         NANOAOD              2211      66010856331649
# 22                            TEST               181         48870000000
# 23                            None                 0      24535172091666
# 24                       CONTAINER                15    1260697442484918
# 25                          PREMIX                25    5837578999210829
# 26       GEN-SIM-DIGI-RAW-HLTDEBUG                 4      22845763444143
# 27                    FEVTDEBUGHLT                17      44508484969031
# 28                      ALCAPROMPT                10       1668187663603
# 29                       RAWAODSIM                 1          3315613890
# 30                    GEN-SIM-DIGI                 1        247592117542
# 31  GEN-SIM-DIGI-RAW-HLTDEBUG-RECO                 1      45944994004079

# %%
DF.limit(100).toPandas()

# %%
48870000000 / 10**12
# Out:
# 0.04887
